# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim_models
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Cargar datos
path = 'reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto 

data['pp'] = data['review_body'].apply(lambda texto: pre_procesado(texto))

data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                                 pp
# 0       es          jewelry        [buen, buena, calidad, buena, presentación]
# 1       es      video_games  [producto, perfecto, salir, casa, nintendo, sw...
# 2       es      video_games  [funciona, nintendo, switch, forma, emparejarl...
# 3       es      video_games  [recomendado, utilizo, pc, dan, ningún, proble...
# 4       es      video_games  [cable, funciona, bien, podria, ser, mas, larg...

# %%
# Crear una representación de los documentos en forma de diccionario
dictionary = Dictionary(data['pp'].values)
#dictionary.token2id  Le asigna a cada palarabra un numero
# Filtrar palabras muy frecuentes o infrecuentes
dictionary.filter_extremes(no_below=5, no_above=0.5)
corpus = [dictionary.doc2bow(text) for text in data['pp'].values]
#corpus
#Train the topic model
model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=7, passes=50, random_state = 28) #random es la semilla
#model

# %%
model.print_topics(num_words= 10)
# Out:
# [(0,
#   '0.053*"bien" + 0.027*"si" + 0.023*"juego" + 0.021*"caja" + 0.017*"español" + 0.014*"cierre" + 0.014*"aunque" + 0.013*"buen" + 0.013*"viene" + 0.013*"va"'),
#  (1,
#   '0.057*"juego" + 0.030*"regalo" + 0.019*"bastante" + 0.019*"bien" + 0.019*"jugar" + 0.018*"bonito" + 0.016*"si" + 0.015*"gustado" + 0.014*"viene" + 0.014*"pena"'),
#  (2,
#   '0.042*"bonitos" + 0.034*"bien" + 0.033*"tamaño" + 0.026*"pendientes" + 0.026*"grandes" + 0.024*"quedan" + 0.021*"pequeños" + 0.016*"calidad" + 0.014*"demasiado" + 0.014*"esperaba"'),
#  (3,
#   '0.081*"calidad" + 0.056*"precio" + 0.039*"buena" + 0.024*"bien" + 0.022*"cadena" + 0.020*"foto" + 0.016*"aunque" + 0.015*"parece" + 0.014*"ve" + 0.014*"mala"'),
#  (4,
#   '0.038*"llegó" + 0.035*"perfecto" + 0.031*"producto" + 0.019*"juego" + 0.017*"buen" + 0.017*"precio" + 0.016*"bien" + 0.016*"si" + 0.015*"pedido" + 0.014*"juegos"'),
#  (5,
#   '0.033*"si" + 0.022*"así" + 0.021*"mando" + 0.019*"queda" + 0.019*"switch" + 0.017*"producto" + 0.017*"bien" + 0.015*"bonito" + 0.015*"original" + 0.014*"amazon"'),
#  (6,
#   '0.047*"llegado" + 0.035*"día" + 0.025*"producto" + 0.024*"llego" + 0.020*"entrega" + 0.018*"nunca" + 0.014*"cumple" + 0.014*"tiempo" + 0.014*"perfecto" + 0.014*"todavía"')]

# %%
lda_display = pyLDAvis.gensim_models.prepare(model, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el802430731550145447647917659"></div>
# <script type="text/javascript">
#
# var ldavis_el802430731550145447647917659_data = {"mdsDat": {"x": [-0.12864672001627275, -0.04878504177325723, -0.02676462277405366, 0.10706476142727298, -0.012872944041965219, -0.12160174037300642, 0.23160630755128253], "y": [-0.11552844469687278, 0.10844641325963536, 0.1998462627294933, 0.006718655466571382, -0.039896581511937784, -0.08919755518080473, -0.07038875006608478], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [18.69333568118324, 16.835046704189278, 13.919927644802799, 13.824571988433734, 13.48987977484465, 12.169399482333368, 11.067838724212933]}, "tinfo": {"Term": ["calidad", "juego", "llegado", "bonitos", "precio", "buena", "lleg\u00f3", "perfecto", "tama\u00f1o", "d\u00eda", "grandes", "pendientes", "cadena", "quedan", "regalo", "si", "peque\u00f1os", "entrega", "llego", "switch", "caja", "queda", "espa\u00f1ol", "nunca", "bien", "jugar", "producto", "foto", "bonito", "aunque", "cadena", "ve", "relaci\u00f3n", "baja", "acabados", "peque\u00f1as", "funci\u00f3n", "excelente", "buena", "cuello", "bajo", "puesta", "mala", "calidad", "resulta", "precioso", "pro", "color", "fina", "piel", "much\u00edsimo", "dorado", "pedir", "principio", "precio", "cuesta", "preciosa", "conjunto", "mismo", "malo", "tan", "foto", "aunque", "peque\u00f1o", "aspecto", "parece", "ps", "bonita", "colgante", "puede", "compr\u00e9", "bien", "bonito", "gusta", "mas", "cumple", "bastante", "ser", "buen", "queda", "producto", "pandora", "jugando", "entretenido", "fan", "comprado", "jugabilidad", "ni\u00f1os", "saga", "tener", "q", "quedado", "divertido", "pens\u00e9", "ningun", "alta", "primera", "peor", "jugar", "merece", "compro", "pocas", "visto", "hijo", "mucha", "gust\u00f3", "bolsa", "caso", "juego", "todas", "regalo", "gustado", "pena", "a\u00f1os", "gusto", "bastante", "viene", "verdad", "bonito", "pulsera", "decir", "amazon", "mas", "vale", "si", "bien", "grande", "menos", "parte", "esperaba", "ahora", "puede", "precio", "a\u00fan", "devolver", "switch", "cargador", "van", "cerrar", "usado", "mont\u00f3n", "sigue", "materiales", "fino", "puedes", "nintendo", "sale", "abrir", "anillo", "genial", "voy", "dice", "lado", "apenas", "funda", "manera", "acabado", "adapta", "pienso", "desear", "pulseras", "consola", "entra", "comprar", "as\u00ed", "queda", "veces", "original", "tal", "mando", "grande", "amazon", "si", "vez", "mal", "bonito", "da", "llega", "producto", "parte", "bien", "mejor", "peque\u00f1o", "despu\u00e9s", "uso", "caja", "solo", "lleg\u00f3", "funcionar", "rapido", "totalmente", "castellano", "falta", "descripci\u00f3n", "dio", "juegazo", "fea", "pedido", "instrucciones", "espero", "juegos", "perfecto", "transporte", "gracias", "perdido", "plazo", "roto", "cuidado", "cosas", "dedo", "compras", "vendedor", "negro", "sony", "condiciones", "dejado", "puse", "pronto", "llegar", "encantado", "muchas", "meses", "ps", "producto", "buen", "tiempo", "pueden", "solo", "juego", "precio", "funciona", "si", "perfectamente", "bien", "caja", "mas", "d\u00eda", "comprar", "dos", "mal", "espa\u00f1ol", "cargar", "usb", "cd", "ruido", "ingles", "f\u00e1cil", "funcionan", "peque\u00f1a", "base", "seguro", "ingl\u00e9s", "enviaron", "junto", "enseguida", "medida", "collar", "perdi\u00f3", "prime", "piedras", "enga\u00f1o", "va", "encant\u00f3", "cierre", "auriculares", "punto", "usar", "presentaci\u00f3n", "ped\u00ed", "\u00fanica", "sonido", "caja", "trae", "dem\u00e1s", "bien", "pone", "versi\u00f3n", "si", "viene", "correcto", "aunque", "pulsera", "funciona", "juego", "d\u00edas", "dos", "buen", "r\u00e1pido", "solo", "producto", "regalo", "momento", "bueno", "gran", "compra", "sido", "bonitos", "grandes", "quedan", "bonitas", "preciosos", "puestos", "peque\u00f1os", "perlas", "tama\u00f1o", "media", "valen", "pendientes", "elegantes", "ponen", "horas", "s\u00e9", "largo", "ajusta", "primero", "brillo", "c\u00f3modos", "alguna", "peso", "vienen", "dan", "dise\u00f1o", "cuanto", "igualmente", "gran", "quiz\u00e1s ...

# %%
d = dictionary.doc2bow(["juego", "bien", "calidad"])
topics = [(cluster[0]+1, cluster[1]) for cluster in model.get_document_topics(d)]
topics
# Out:
# [(1, 0.035961706),
#  (2, 0.3859157),
#  (3, 0.035847858),
#  (4, 0.43494788),
#  (5, 0.035815116),
#  (6, 0.03576708),
#  (7, 0.03574467)]

# %%
def get_doc_top_n(text_processed, n):
    d = dictionary.doc2bow(text_processed)
    topics = dict(model.get_document_topics(d))
    try:
        return topics[n]
    except:
        return None

# %%
for t in range(0,7):
    top_name = f"topic_{t}"
    data[top_name] = data['pp'].apply(lambda doc: get_doc_top_n(doc, t))

for t in range(0,7):
    print(f"*********************************** TOPIC {t} ***********************************")
    topic = f"topic_{t}"
    for i,articulo in enumerate(data.sort_values('topic_0', ascending=False)['review_body'].values[:5]):
        print(f"review_body #{i}")
        print(articulo[:500])
        print()
    print()
# Out:
# *********************************** TOPIC 0 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
#
#
# *********************************** TOPIC 1 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
#
#
# *********************************** TOPIC 2 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
#
#
# *********************************** TOPIC 3 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
#
#
# *********************************** TOPIC 4 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
#
#
# *********************************** TOPIC 5 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
#
#
# *********************************** TOPIC 6 ***********************************
# review_body #0
# Quizá un poco caro por 25€ pero es que el juego es brutal. Uno de los mejores. Esta edición tiene todo el contenido disponible y funciona perfectamente en Xbox One y se instala en Español. La carátula es exactamente la que viene en la foto, la que pone Xbox One y Xbox 360. Pero OJO, es versión NTSC, si lo compras para tu Xbox 360 PAL no te funcionará
#
# review_body #1
# La consola llegó con la caja rota y desprecintada, y con signos de haber sido usada. En estas condiciones, no me ofrece ninguna confianza. Si el producto ha sido devuelto por algún motivo, deberían de avisarlo a la hora de la compra, y el cliente decidir si lo quiere en esas condiciones o no.
#
# review_body #2
# Engaño ,me han eviado una versión que no es uk o no viene en español,es una version polaca que solo viene en ingles polaco o ruso, dicen que al iniciar el juego se pone solo ,pero no , no hay manera de cambiarlo,y si tengo ps4 española y en español.
#
# review_body #3
# En ninguno de los puertos USB reconoce el disco duro externo (Toshiba Canvio), en los puertos USB 2.0 no funcionan los Auriculares Platinum de Sony. La única funcionalidad correcta es la de cargar los mandos, para lo cual me sobra con los dos puertos que trae la consola. Muy mala experiencia, ha sido tirar el dinero, no lo recomiendo.
#
# review_body #4
# Un buen colgante de buena calidad, y de un gran envío rápido. La única pega es que las dos cadenas se lían entre sí muchas veces, es elegante, pero siempre se están liando entre sí, por lo demás bien.
